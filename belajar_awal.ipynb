# %% [markdown]
# <a href="https://colab.research.google.com/github/Zuckmo/Belajar-Data-Science/blob/main/belajar_awal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

my_math = 20, 30, 50, 40
np.mean(my_math)
# Out:
# 35.0

# %%
your_math = 270, 30, 50, 490
np.mean(your_math)
# Out:
# 210.0

# %%
x = 3
if x>0:
  print("positive")
elif x==0:
  print("zero")
else:
  "gatau"
# Out:
# positive

# %%
def nilai(x):

  if(x>90):
    print("Grade is A")
  elif (x>70 and x<=90):
    print("Grade is B")
  else:
    print("Grade is C")
    return x
  
nilai(10)
nilai(100)
nilai(70)
# Out:
# Grade is C
# Grade is A
# Grade is C
# 70

# %%
x = 50
if x>40:print("X lebih besar")
print(10%3)
# Out:
# X lebih besar
# 1

# %%
for i in range(5):print('AKU CINTA KAMU')
for i in "123456":print(i)
for i in range(20,30,2):print(i)
# Out:
# AKU CINTA KAMU
# AKU CINTA KAMU
# AKU CINTA KAMU
# AKU CINTA KAMU
# AKU CINTA KAMU
# 1
# 2
# 3
# 4
# 5
# 6
# 20
# 22
# 24
# 26
# 28

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import cmath

# %%
a = math.exp(21)
b = math.exp(-1.2)
print(a)
print(b)
# Out:
# 1318815734.4832146
# 0.30119421191220214

# %%
nk = {'Jono':80, 'Joni':90, 'Susi':60}
print("nilai joni", nk["Joni"])
nk["Jonni"]=[100]

nk.update({"SONO":78, "SONI":77, "GUS":98})

del nk["Jonni"]
print(nk)
# Out:
# nilai joni 90
# {'Jono': 80, 'Joni': 90, 'Susi': 60, 'SONO': 78, 'SONI': 77, 'GUS': 98}

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# /usr/local/lib/python3.7/dist-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]
# /usr/local/lib/python3.7/dist-packages/datascience/tables.py:17: MatplotlibDeprecationWarning:
#
# The 'warn' parameter of use() is deprecated since Matplotlib 3.1 and will be removed in 3.3.  If any parameter follows 'warn', they should be pass as keyword, not positionally.
#
# /usr/local/lib/python3.7/dist-packages/datascience/util.py:10: MatplotlibDeprecationWarning:
#
# ...

# %%
import pandas as pd

from google.colab import files
filenya = files.upload()
# Out:
#      <input type="file" id="files-017fcbd3-3e5a-4072-b554-1438fbd60140" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-017fcbd3-3e5a-4072-b554-1438fbd60140">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv

# %%
df=pd.read_csv("data.csv")
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ced11615-70bc-45d7-bb12-7c4ff05e7547" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ced11615-70bc-45d7-bb12-7c4ff05e7547">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.xlsx to data.xlsx
# ...

# %%
import pandas as pd
df=pd.read_excel("data.xlsx")
df.head(4)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
#
# [4 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df[["Age", "Sex"]]
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
df.iloc[4:8]
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
#
# [4 rows x 12 columns]

# %%
import pandas as pd
df=pd.read_excel("data.xlsx")
df[df["Age"]==35.0]
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 3              4         1       1  ...   53.1000  C123         S
# 4              5         0       3  ...    8.0500   NaN         S
# 20            21         0       2  ...   26.0000   NaN         S
# 211          212         1       2  ...   21.0000   NaN         S
# 230          231         1       1  ...   83.4750   C83         S
# 258          259         1       1  ...  512.3292   NaN         C
# 269          270         1       1  ...  135.6333   C99         S
# 279          280         1       3  ...   20.2500   NaN         S
# 363          364         0       3  ...    7.0500   NaN         S
# 383          384         1       1  ...   52.0000   NaN         S
# 486          487         1       1  ...   90.0000   C93         S
# 590          591         0       3  ...    7.1250   NaN         S
# 604          605         1       1  ...   26.5500   NaN         C
# ...

# %%
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}

df1 = pd.DataFrame(data)
df1
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Address', 'Qualification'], dtype='object')

# %%
df.iloc[:,:3]
# Out:
#      Name  Age    Address
# 0     Jai   27      Delhi
# 1  Princi   24     Kanpur
# 2  Gaurav   22  Allahabad
# 3    Anuj   32    Kannauj

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d7d70e45-9cfa-4c79-8164-30c56f9ef2bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d7d70e45-9cfa-4c79-8164-30c56f9ef2bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index.csv to index.csv
# ...

# %%
df2 = pd.read_csv("index.csv")
df2
# Out:
#      A  B   C   D  E  F      G      H       I     J  K  L
# 0    C  A   8   0  S  0   COIL  0.700   610.0     0  0  3
# 1    C  R   0   0  S  0   COIL  3.200   610.0     0  0  3
# 2    C  R   0   0  S  0  SHEET  0.700  1300.0   762  0  3
# 3    C  A   0  60  ?  0   COIL  2.801   385.1     0  0  3
# 4    C  A   0  60  ?  0  SHEET  0.801   255.0   269  0  3
# ..  .. ..  ..  .. .. ..    ...    ...     ...   ... .. ..
# 252  C  A   0  60  ?  0   COIL  0.799   609.0     0  0  3
# 253  C  R   6   0  ?  0  SHEET  1.000   610.0  4880  0  3
# 254  C  A   0  50  ?  0   COIL  0.600    20.0     0  0  3
# 255  C  K  45   0  ?  0   COIL  0.600   900.0     0  0  3
# 256  C  R   6   0  ?  0  SHEET  1.000   610.0   762  0  3
#
# [257 rows x 12 columns]

# %%
df2.iloc[:,:3]
# Out:
#      A  B   C
# 0    C  A   8
# 1    C  R   0
# 2    C  R   0
# 3    C  A   0
# 4    C  A   0
# ..  .. ..  ..
# 252  C  A   0
# 253  C  R   6
# 254  C  A   0
# 255  C  K  45
# 256  C  R   6
#
# [257 rows x 3 columns]

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b6e269f4-791d-4ef4-b6d8-b884daf02f00" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b6e269f4-791d-4ef4-b6d8-b884daf02f00">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bigmart_data.csv to bigmart_data.csv
# ...

# %%
import pandas as pd
df3 = pd.read_csv("bigmart_data.csv")
df3
# Out:
#      Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0              FDA15        9.300  ...  Supermarket Type1          3735.1380
# 1              DRC01        5.920  ...  Supermarket Type2           443.4228
# 2              FDN15       17.500  ...  Supermarket Type1          2097.2700
# 3              FDX07       19.200  ...      Grocery Store           732.3800
# 4              NCD19        8.930  ...  Supermarket Type1           994.7052
# ...              ...          ...  ...                ...                ...
# 8518           FDF22        6.865  ...  Supermarket Type1          2778.3834
# 8519           FDS36        8.380  ...  Supermarket Type1           549.2850
# 8520           NCJ29       10.600  ...  Supermarket Type1          1193.1136
# 8521           FDN46        7.210  ...  Supermarket Type2          1845.5976
# 8522           DRG01       14.800  ...  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
DataFrame.sort(df3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e887758557cc> in <module>()
# ----> 1 DataFrame.sort(df3)
#
# NameError: name 'DataFrame' is not defined
